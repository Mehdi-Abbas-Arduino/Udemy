# %%
f = open('practice.txt',mode='w+')
f.write("This is a test string")
f.close()

# %%
f = open('practice.txt',mode='r')
print(f.read())
f.seek(0)
f.close()
# Out:
# This is a test string

# %%
import os

# %%
os.getcwd() # it reports back working directory
# Out:
# 'e:\\Udemy\\UNIT 09'

# %%
os.listdir()
# Out:
# ['collections.ipynb', 'os.ipynb', 'practice.txt']

# %%
os.listdir('C:\\Users')
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'Public', 'User']

# %%
import shutil

# %%
# shutil.move('practice.txt','C:\\Users\\Desktop')

# %%
os.chmod('practice.txt', 0o600)

# %%
os.listdir('C:\\')
# Out:
# ['$Recycle.Bin',
#  '$WinREAgent',
#  'Config.Msi',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'Intel',
#  'MinGW',
#  'MSOCache',
#  'OneDriveTemp',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'swapfile.sys',
#  'System Volume Information',
#  'Users',
#  'Windows']

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['collections.ipynb', 'os.ipynb', 'practice.txt']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['collections.ipynb', 'os.ipynb']

# %%
for folder,sub_folders,files in os.walk('E:\\'):
    print(folder)
    print('\n')
    for subfolders in sub_folders:
        print(subfolders)
        print('\n')
    for f in files:
        print(f)
        print('\n')
# Out:
# E:\
#
#
# $RECYCLE.BIN
#
#
# Aqib Khan Python
#
#
# Assignment Saylani
#
#
# Assignments
#
#
# C course
#
#
# Capcut Course
#
#
# Chemistry papst papers
#
#
# Ciet Practical programming
#
#
# Ciet Practical programming -Homework
#
#
# Computer Science - past papers programming with python
#
#
# Computer Science Olevel paper 2
#
#
# DSA using C
#
#
# Governor Sindh Initative Courses
#
#
# HackeRank
#
#
# HTML practice
#
#
# Java course
#
#
# Kotlin
#
#
# Musicify
#
#
# OOPS
#
#
# Past Paper Python
#
#
# Python Packages
#
#
# SMIT
#
#
# System Volume Information
#
#
# Udemy
#
#
# Web Development
#
#
# 1123_s23_ms_21.pdf
#
#
# 2210_All Past Paper till 2022_merged_light water mark.pdf
#
#
# 2210_Pseudocode_Guide_for_Teachers_(for_examination_from_2016) (1).pdf
#
#
# All paper 2 CS.pdf
#
#
# All_paper_2_CS[1].pdf
#
#
# Electrolysis By SOS.pdf
#
#
# grade_2_growing[1].docx
#
#
# introduction-to-ubuntu-linux-english.pdf
#
#
# Match the following and mark the correct option.docx
#
#
# ...
